# %% [markdown]
# # Introduction to Keras and Shallow Networks
#
# In this lab we will create our first neural network. It will be a shallow one, over a small dataset, so it is not a good example of a real-life problem where neural networks shine, but it will be a great way to understand the network architectures and what can we do with the model.
#
# In this lab, and in general in future examples, we will closely follow the book "Deep Learning with Python" by Chollet. The library has copies of the book.
#
# ## Loading the data
#
# We will import one of the data examples from Keras itself: House Prices in Boston.
#
# But first, what is Keras?
#
# [Keras](https://keras.io/) is the high level API of [tensorflow](https://www.tensorflow.org/), Google's deep learning software. Deep Learning requires a set of very sophisticated optimizers and computational calculations, so it can be tricky to program directly. Luckily for us, we can simply use Keras to call the more sophisticated programs that will do the heavy lifting for us.
#
# Technically, Keras is a "front-end", while the calculation engine will be a "backend". Those backends will actually call a backend of their own which will communicate with the machine itself.
#
# If you want to configure your own environment in your PC, and have an Nvidia GPU at home or your laptop, please follow the following steps:
#
# 1. Install Anaconda Python from [here](https://www.anaconda.com/distribution/).
#
# 2. Follow the steps [here](https://shawnhymel.com/2034/how-to-install-tensorflow-on-windows/) on Windows to configure your Python environment with tensorflow. There are many, many tutorials online on how to do this for multiple platforms. Other tutorials here for [Mac](https://www.pyimagesearch.com/2019/01/30/macos-mojave-install-tensorflow-and-keras-for-deep-learning/) or [Linux](https://www.pyimagesearch.com/2019/01/30/ubuntu-18-04-install-tensorflow-and-keras-for-deep-learning/).
#
# We will continue using Google Colab's environment, so you don't need to do this. What we need to do is to change our execution environment to a GPU one. For that:
#
# - Click Runtime
# - Select "Change runtime type"
# - In the menu, in the combo box below "Hardware Accelerator" select GPU.
#
# There is an even more powerful environment: TPU, but this requires a change in coding so we will omit it for this introduction. If you are curious and want to try it out, check out [this Colab notebook](https://colab.research.google.com/notebooks/tpu.ipynb).
#
# Now we are ready to use Keras!

# %% [markdown]
# ## Keras Sequential API
#
# The easiest model that can be constructed in Keras is a sequential model. This is the typical neural network with one input layer, and one output layer, and a linear sequence of as many layers as we want in-between. A tutorial for the sequencial API can be found [here](https://keras.io/getting-started/sequential-model-guide/).
#
# First let's load the data.

# %%
import tensorflow.keras as keras
from keras.datasets import boston_housing
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %%
print('Size of the training set: ', train_data.shape)
print('Size of the test set: ', test_data.shape)
# Out:
# Size of the training set:  (404, 13)
# Size of the test set:  (102, 13)

# %% [markdown]
# This is a very small dataset, with only 404 cases for training, 102 for testing, 13 variables, and 1 target representing the median house price in Boston for the neighbourhood. The variables can be found [here](https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html).
#
# We have one problem: All variables are in different scales. The following code normalizes the data. Remember that, to avoid test set leak, you should normalize the data using the information from the train test and applying it to the test set. Scikit-Learn has the useful [StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html) function that you can use.

# %%
from sklearn.preprocessing import StandardScaler

# Create the transformer.
scaler = StandardScaler()

# Train in the train set and change the original data
train_data = scaler.fit_transform(train_data)

# Apply to the test set
test_data = scaler.transform(test_data)

# %% [markdown]
# Now we can create our model. We want to build the following architecture:
#
# ![](https://drive.google.com/uc?export=view&id=1CfIe77tmoQrh4QEBFZtabYpiM3rdNOOs)

# %% [markdown]
# This example uses the optimizer SGD, the most basic optimizer. There are many optimizers, but as a rule of thumb, test  Adam first, and if it does not work, test SGD and RMSProp. **All of them solve the same backpropagation problem**, they are just tuned to certain data structures. A great comparison of different optimization algorithms can be found [here](https://www.ruder.io/optimizing-gradient-descent/).
#
# To construct the model, we create a "model" object using Keras API. This is simply a container which will hold the general structure of our model, and we will add layers to it. Let's import the layers and the models helper functions.

# %%
from keras import models
from keras import layers

# %% [markdown]
# Now, let's build an empty sequential model. Let's name it "model" (yeah, original).

# %%
model = models.Sequential()

# %% [markdown]
# This is just an empty model, it does not have any layers! Let's add the first hidden layer. For each model object that we have, the function "add" will append a layer stacking one on top of the other.
#
# Remember, we want to add a fully-connected (Dense) layer, with 64 hidden neurons and ReLU activation function. We also need to tell this first layer what input to expect, we do this with the "input_shape" option. In this case, we are giving it a vector of size 13.

# %%
model.add(layers.Dense(64,                  # The number of neurons
                       activation = 'relu', # The type of activation
                       input_shape = (13,)  # The input shape. It is only necessary for the layer connected to the input.
                      )
         )

# %% [markdown]
# Keras supports many activations. The list can be seen [here](https://keras.io/activations/). It also has many types of layers! The list [here](https://keras.io/layers/about-keras-layers/). Don't worry about this now, we will use many in the coming labs.
#
# Let's add one more Dense layer.

# %%
model.add(layers.Dense(64, activation = 'relu'))

# %% [markdown]
# Note that now we didn't need to specify inputs and outputs, Keras will deduce them from the previous layer (thus the sequential structure!).
#
# Now, let's add the final layer, *i.e.*, output layer. This is simply a Dense layer, of size 1 and ReLU activation. As this is a regression problem, we want outputs between $(0,\infty)$.

# %%
model.add(layers.Dense(1, activation = 'relu'))

# %% [markdown]
# With the model ready, the last step is to tell it how to train it. For this, we tell it to "compile it", and give it an optimizer. Note the error is the Minimum Square Error (MSE), which is used for regressions. We will see several more for different applications, but the list can be checked [here](https://keras.io/losses/).

# %%
opt = keras.optimizers.SGD(learning_rate=0.001) # 10^-3, 10^-4, 10^-6
# opt = keras.optimizers.ADAM()
model.compile(optimizer = opt,                       # The optimizer just defined 
              loss = keras.losses.MeanSquaredError() # The loss
              )

# %% [markdown]
# The optimizer has a learning rate parameter that needs to be set. For this lab we will ignore it and just use the default, but we will dig much deeper into this in the future.
#
# We can take a look at the model structure by running the following command:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                896
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Or we can show it much more nicely in a picture.

# %%
import matplotlib.pyplot as plt
from keras.utils.vis_utils import plot_model
from IPython.display import Image
# %matplotlib inline

plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')
Image(retina=True, filename='model.png')

# %% [markdown]
# ## Training and testing
#
# Now we can simply train the model! It follows the same fitting structure of scikit-learn: We use a `fit` function  to tell the model the data it needs to train on.

# %%
history = model.fit(train_data, #X
                    train_targets, #Y
                    epochs = 100, # Rounds of training
                    batch_size=128, # Size of elements
                    validation_split= 0.25) # Validation split
# Out:
# Epoch 1/100
# 3/3 [==============================] - 5s 88ms/step - loss: 540.4596 - val_loss: 659.0345
# Epoch 2/100
# 3/3 [==============================] - 0s 24ms/step - loss: 512.4565 - val_loss: 615.3676
# Epoch 3/100
# 3/3 [==============================] - 0s 18ms/step - loss: 471.3565 - val_loss: 557.5909
# Epoch 4/100
# 3/3 [==============================] - 0s 15ms/step - loss: 415.0616 - val_loss: 468.4698
# Epoch 5/100
# 3/3 [==============================] - 0s 15ms/step - loss: 331.1288 - val_loss: 339.6752
# Epoch 6/100
# 3/3 [==============================] - 0s 24ms/step - loss: 218.3770 - val_loss: 197.0965
# Epoch 7/100
# 3/3 [==============================] - 0s 15ms/step - loss: 114.7905 - val_loss: 118.5746
# Epoch 8/100
# 3/3 [==============================] - 0s 15ms/step - loss: 66.9922 - val_loss: 83.8245
# Epoch 9/100
# 3/3 [==============================] - 0s 15ms/step - loss: 49.1582 - val_loss: 70.1287
# Epoch 10/100
# 3/3 [==============================] - 0s 16ms/step - loss: 41.3493 - val_loss: 59.8931
# Epoch 11/100
# 3/3 [==============================] - 0s 14ms/step - loss: 35.5408 - val_loss: 53.7589
# Epoch 12/100
# 3/3 [==============================] - 0s 16ms/step - loss: 31.7341 - val_loss: 48.2522
# Epoch 13/100
# 3/3 [==============================] - 0s 15ms/step - loss: 28.8527 - val_loss: 44.1388
# Epoch 14/100
# 3/3 [==============================] - 0s 15ms/step - loss: 27.0505 - val_loss: 42.6685
# Epoch 15/100
# 3/3 [==============================] - 0s 14ms/step - loss: 25.8429 - val_loss: 40.7787
# Epoch 16/100
# 3/3 [==============================] - 0s 14ms/step - loss: 24.7048 - val_loss: 39.4510
# Epoch 17/100
# 3/3 [==============================] - 0s 15ms/step - loss: 23.6342 - val_loss: 38.3870
# Epoch 18/100
# 3/3 [==============================] - 0s 15ms/step - loss: 22.8437 - val_loss: 36.9607
# Epoch 19/100
# 3/3 [==============================] - 0s 14ms/step - loss: 22.1121 - val_loss: 35.6783
# Epoch 20/100
# 3/3 [==============================] - 0s 15ms/step - loss: 21.5117 - val_loss: 33.8437
# Epoch 21/100
# 3/3 [==============================] - 0s 15ms/step - loss: 20.8404 - val_loss: 33.1197
# Epoch 22/100
# 3/3 [==============================] - 0s 17ms/step - loss: 20.4412 - val_loss: 31.6576
# Epoch 23/100
# 3/3 [==============================] - 0s 15ms/step - loss: 19.8527 - val_loss: 31.0923
# Epoch 24/100
# 3/3 [==============================] - 0s 15ms/step - loss: 19.3765 - val_loss: 30.9071
# Epoch 25/100
# 3/3 [==============================] - 0s 15ms/step - loss: 19.0139 - val_loss: 30.4748
# Epoch 26/100
# 3/3 [==============================] - 0s 15ms/step - loss: 18.6835 - val_loss: 30.3263
# Epoch 27/100
# 3/3 [==============================] - 0s 15ms/step - loss: 18.6579 - val_loss: 27.8411
# Epoch 28/100
# 3/3 [==============================] - 0s 17ms/step - loss: 17.9248 - val_loss: 26.4501
# Epoch 29/100
# 3/3 [==============================] - 0s 24ms/step - loss: 17.4512 - val_loss: 26.4431
# Epoch 30/100
# 3/3 [==============================] - 0s 15ms/step - loss: 17.0628 - val_loss: 25.8767
# Epoch 31/100
# 3/3 [==============================] - 0s 15ms/step - loss: 16.7954 - val_loss: 25.6010
# Epoch 32/100
# 3/3 [==============================] - 0s 15ms/step - loss: 16.6023 - val_loss: 24.9861
# Epoch 33/100
# 3/3 [==============================] - 0s 14ms/step - loss: 16.3585 - val_loss: 23.3338
# Epoch 34/100
# 3/3 [==============================] - 0s 14ms/step - loss: 15.9465 - val_loss: 23.5488
# Epoch 35/100
# 3/3 [==============================] - 0s 14ms/step - loss: 15.5802 - val_loss: 23.6709
# Epoch 36/100
# 3/3 [==============================] - 0s 22ms/step - loss: 15.3219 - val_loss: 23.1130
# Epoch 37/100
# 3/3 [==============================] - 0s 15ms/step - loss: 15.0545 - val_loss: 23.2880
# Epoch 38/100
# 3/3 [==============================] - 0s 15ms/step - loss: 14.8910 - val_loss: 22.9370
# Epoch 39/100
# 3/3 [==============================] - 0s 14ms/step - loss: 14.8862 - val_loss: 22.6126
# Epoch 40/100
# 3/3 [==============================] - 0s 14ms/step - loss: 14.4908 - val_loss: 22.0904
# Epoch 41/100
# 3/3 [==============================] - 0s 19ms/step - loss: 14.3099 - val_loss: 22.0037
# Epoch 42/100
# 3/3 [==============================] - 0s 15ms/step - loss: 14.1160 - val_loss: 21.9416
# Epoch 43/100
# 3/3 [==============================] - 0s 15ms/step - loss: 14.0305 - val_loss: 22.0374
# Epoch 44/100
# 3/3 [==============================] - 0s 15ms/step - loss: 13.9637 - val_loss: 21.2740
# Epoch 45/100
# 3/3 [==============================] - 0s 16ms/step - loss: 13.6029 - val_loss: 20.6339
# Epoch 46/100
# 3/3 [==============================] - 0s 15ms/step - loss: 13.4919 - val_loss: 20.8169
# Epoch 47/100
# 3/3 [==============================] - 0s 14ms/step - loss: 13.3954 - val_loss: 20.2704
# Epoch 48/100
# 3/3 [==============================] - 0s 14ms/step - loss: 13.1263 - val_loss: 20.3082
# Epoch 49/100
# 3/3 [==============================] - 0s 15ms/step - loss: 13.0985 - val_loss: 20.2024
# Epoch 50/100
# 3/3 [==============================] - 0s 17ms/step - loss: 12.9138 - val_loss: 19.8515
# Epoch 51/100
# 3/3 [==============================] - 0s 14ms/step - loss: 12.7889 - val_loss: 19.5852
# Epoch 52/100
# 3/3 [==============================] - 0s 14ms/step - loss: 12.6779 - val_loss: 19.2439
# Epoch 53/100
# 3/3 [==============================] - 0s 15ms/step - loss: 12.6328 - val_loss: 18.8151
# Epoch 54/100
# 3/3 [==============================] - 0s 14ms/step - loss: 12.5275 - val_loss: 19.0407
# Epoch 55/100
# 3/3 [==============================] - 0s 14ms/step - loss: 12.3550 - val_loss: 19.2196
# Epoch 56/100
# 3/3 [==============================] - 0s 14ms/step - loss: 12.3503 - val_loss: 18.1652
# Epoch 57/100
# 3/3 [==============================] - 0s 14ms/step - loss: 12.2399 - val_loss: 18.7291
# Epoch 58/100
# 3/3 [==============================] - 0s 16ms/step - loss: 12.0835 - val_loss: 18.5311
# Epoch 59/100
# 3/3 [==============================] - 0s 15ms/step - loss: 11.9535 - val_loss: 17.5990
# Epoch 60/100
# 3/3 [==============================] - 0s 16ms/step - loss: 11.9509 - val_loss: 17.3813
# Epoch 61/100
# 3/3 [==============================] - 0s 26ms/step - loss: 11.7025 - val_loss: 17.2794
# Epoch 62/100
# 3/3 [==============================] - 0s 15ms/step - loss: 11.7110 - val_loss: 17.2402
# Epoch 63/100
# 3/3 [==============================] - 0s 14ms/step - loss: 11.6428 - val_loss: 17.2552
# Epoch 64/100
# 3/3 [==============================] - 0s 17ms/step - loss: 11.5345 - val_loss: 16.9341
# Epoch 65/100
# 3/3 [==============================] - 0s 17ms/step - loss: 11.4472 - val_loss: 16.8443
# Epoch 66/100
# 3/3 [==============================] - 0s 20ms/step - loss: 11.3889 - val_loss: 16.9174
# Epoch 67/100
# 3/3 [==============================] - 0s 23ms/step - loss: 11.2678 - val_loss: 16.5156
# Epoch 68/100
# 3/3 [==============================] - 0s 23ms/step - loss: 11.2680 - val_loss: 16.7834
# Epoch 69/100
# 3/3 [==============================] - 0s 32ms/step - loss: 11.1425 - val_loss: 16.5146
# Epoch 70/100
# 3/3 [==============================] - 0s 29ms/step - loss: 11.1567 - val_loss: 16.2535
# Epoch 71/100
# 3/3 [==============================] - 0s 22ms/step - loss: 11.0473 - val_loss: 16.4731
# Epoch 72/100
# 3/3 [==============================] - 0s 28ms/step - loss: 10.9737 - val_loss: 15.8958
# Epoch 73/100
# 3/3 [==============================] - 0s 19ms/step - loss: 10.9669 - val_loss: 15.9482
# Epoch 74/100
# 3/3 [==============================] - 0s 29ms/step - loss: 10.8962 - val_loss: 15.7657
# Epoch 75/100
# 3/3 [==============================] - 0s 30ms/step - loss: 10.7298 - val_loss: 15.6209
# Epoch 76/100
# 3/3 [==============================] - 0s 28ms/step - loss: 10.6645 - val_loss: 15.7044
# Epoch 77/100
# 3/3 [==============================] - 0s 29ms/step - loss: 10.6905 - val_loss: 15.3897
# Epoch 78/100
# 3/3 [==============================] - 0s 30ms/step - loss: 10.6147 - val_loss: 15.6639
# Epoch 79/100
# 3/3 [==============================] - 0s 22ms/step - loss: 10.5750 - val_loss: 15.3789
# Epoch 80/100
# 3/3 [==============================] - 0s 28ms/step - loss: 10.4842 - val_loss: 15.4728
# Epoch 81/100
# 3/3 [==============================] - 0s 32ms/step - loss: 10.4804 - val_loss: 15.4201
# Epoch 82/100
# 3/3 [==============================] - 0s 20ms/step - loss: 10.4277 - val_loss: 15.3751
# Epoch 83/100
# 3/3 [==============================] - 0s 21ms/step - loss: 10.3685 - val_loss: 15.0554
# Epoch 84/100
# 3/3 [==============================] - 0s 28ms/step - loss: 10.4686 - val_loss: 15.0063
# Epoch 85/100
# 3/3 [==============================] - 0s 31ms/step - loss: 10.2862 - val_loss: 14.8488
# Epoch 86/100
# 3/3 [==============================] - 0s 20ms/step - loss: 10.2480 - val_loss: 14.5064
# Epoch 87/100
# 3/3 [==============================] - 0s 30ms/step - loss: 10.1906 - val_loss: 14.8591
# Epoch 88/100
# 3/3 [==============================] - 0s 22ms/step - loss: 10.0890 - val_loss: 14.7106
# Epoch 89/100
# 3/3 [==============================] - 0s 20ms/step - loss: 10.0552 - val_loss: 14.6304
# Epoch 90/100
# 3/3 [==============================] - 0s 29ms/step - loss: 10.0605 - val_loss: 14.7613
# Epoch 91/100
# 3/3 [==============================] - 0s 28ms/step - loss: 10.1432 - val_loss: 14.8775
# Epoch 92/100
# 3/3 [==============================] - 0s 29ms/step - loss: 10.0143 - val_loss: 14.6931
# Epoch 93/100
# 3/3 [==============================] - 0s 20ms/step - loss: 9.9405 - val_loss: 14.7683
# Epoch 94/100
# 3/3 [==============================] - 0s 22ms/step - loss: 9.8702 - val_loss: 14.3265
# Epoch 95/100
# 3/3 [==============================] - 0s 21ms/step - loss: 9.8087 - val_loss: 14.4459
# Epoch 96/100
# 3/3 [==============================] - 0s 32ms/step - loss: 9.7681 - val_loss: 14.3651
# Epoch 97/100
# 3/3 [==============================] - 0s 28ms/step - loss: 9.7454 - val_loss: 14.3406
# Epoch 98/100
# 3/3 [==============================] - 0s 24ms/step - loss: 9.8251 - val_loss: 13.8837
# Epoch 99/100
# 3/3 [==============================] - 0s 28ms/step - loss: 9.7063 - val_loss: 14.0407
# Epoch 100/100
# 3/3 [==============================] - 0s 20ms/step - loss: 9.7209 - val_loss: 14.1856

# %% [markdown]
# Done! Let's examine the command in detail:
#
# - The first two arguments give us the traning data and the training targets. These should always be Numpy arrays, or other compatible tensors.
#
# - epochs: Neural networks are trained using batches of data, which are shuffled and then fed back to the network. Each full pass of the data is called an "Epoch". We will use the number of epochs to control overfitting with the validation sample.
#
# - batch_size: For big data models, it is not possible to train the model with all data at once, as could be done here. The reason for that is that the model may not fit in memory, or that we need to stream data from an online source. The traditional way is to train in "batches" (shuffled subsets). Recommended batches size are between 32 (for big applications) to 256 (for small problems). In general, we want to keep it small to create "diversity" in the data.
#
# - validation_split: As this model is *very* prone to overfitting, we need to control it somehow. The validation data will help us with this. We will stop training as soon as we start worsening the validation sample. That will be the cut for the epochs in later iterations. We use a 25% split for validation cases. Another alternative is to provide a new set of data to use as validation data, we would use  "validation_data = (val_train, val_target)" instead of this split commmand.
#
# The output we currently have gives us a training loss and a validation loss. This is measured in MSE. But, should we keep training? Are we making any gains?
#
# The following code allows us to visualize the regression metrics.

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Is it worth it to retrain? If you run the "fit" command again, Keras will optimize *over the parameters already found*, so we would actually be improving the result over the training set (but potentially worsening it over the validation set!). The goal is to find a number of epochs that gives us the best result.
#
# In our case: the validation loss and the training loss are still going down! We can continue training. Let's give it 100 more epochs.

# %%
history = model.fit(train_data,
                    train_targets,
                    epochs = 100,
                    batch_size=128,
                    validation_split= 0.25)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 30ms/step - loss: 9.6336 - val_loss: 13.6541
# Epoch 2/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.5775 - val_loss: 13.7142
# Epoch 3/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.5100 - val_loss: 13.6613
# Epoch 4/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.5146 - val_loss: 13.7574
# Epoch 5/100
# 3/3 [==============================] - 0s 24ms/step - loss: 9.5378 - val_loss: 13.4264
# Epoch 6/100
# 3/3 [==============================] - 0s 25ms/step - loss: 9.5204 - val_loss: 13.3449
# Epoch 7/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.5375 - val_loss: 13.1617
# Epoch 8/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.5423 - val_loss: 13.5257
# Epoch 9/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.3837 - val_loss: 13.4079
# Epoch 10/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.4965 - val_loss: 13.3140
# Epoch 11/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.2688 - val_loss: 13.3241
# Epoch 12/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.2527 - val_loss: 13.1389
# Epoch 13/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.3334 - val_loss: 13.0500
# Epoch 14/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.2404 - val_loss: 13.3592
# Epoch 15/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.2101 - val_loss: 13.0315
# Epoch 16/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.1460 - val_loss: 13.1191
# Epoch 17/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.1045 - val_loss: 13.2131
# Epoch 18/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.0805 - val_loss: 13.3378
# Epoch 19/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.0753 - val_loss: 13.1852
# Epoch 20/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.0702 - val_loss: 12.8809
# Epoch 21/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.0038 - val_loss: 12.9990
# Epoch 22/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.9937 - val_loss: 13.0197
# Epoch 23/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.9745 - val_loss: 13.1372
# Epoch 24/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.9759 - val_loss: 12.9747
# Epoch 25/100
# 3/3 [==============================] - 0s 17ms/step - loss: 8.9154 - val_loss: 12.8300
# Epoch 26/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.9068 - val_loss: 12.8987
# Epoch 27/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.8862 - val_loss: 13.0726
# Epoch 28/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.9134 - val_loss: 12.8532
# Epoch 29/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.8416 - val_loss: 12.7951
# Epoch 30/100
# 3/3 [==============================] - 0s 20ms/step - loss: 8.9173 - val_loss: 13.0011
# Epoch 31/100
# 3/3 [==============================] - 0s 21ms/step - loss: 8.8537 - val_loss: 12.6294
# Epoch 32/100
# 3/3 [==============================] - 0s 15ms/step - loss: 8.8823 - val_loss: 12.5183
# Epoch 33/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.7461 - val_loss: 12.4779
# Epoch 34/100
# 3/3 [==============================] - 0s 15ms/step - loss: 8.7291 - val_loss: 12.3019
# Epoch 35/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.7377 - val_loss: 12.4547
# Epoch 36/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.7863 - val_loss: 12.1422
# Epoch 37/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.7002 - val_loss: 12.3583
# Epoch 38/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.6695 - val_loss: 12.3889
# Epoch 39/100
# 3/3 [==============================] - 0s 18ms/step - loss: 8.7349 - val_loss: 12.3414
# Epoch 40/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.5960 - val_loss: 12.4017
# Epoch 41/100
# 3/3 [==============================] - 0s 15ms/step - loss: 8.5836 - val_loss: 12.4570
# Epoch 42/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.6628 - val_loss: 12.5425
# Epoch 43/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.5774 - val_loss: 12.4728
# Epoch 44/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.5424 - val_loss: 12.2558
# Epoch 45/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.5726 - val_loss: 12.1177
# Epoch 46/100
# 3/3 [==============================] - 0s 19ms/step - loss: 8.5717 - val_loss: 12.2022
# Epoch 47/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.5097 - val_loss: 12.0507
# Epoch 48/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.5367 - val_loss: 11.8614
# Epoch 49/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.5195 - val_loss: 12.1500
# Epoch 50/100
# 3/3 [==============================] - 0s 23ms/step - loss: 8.4785 - val_loss: 12.1270
# Epoch 51/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.5261 - val_loss: 11.7575
# Epoch 52/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.4911 - val_loss: 12.0582
# Epoch 53/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.4134 - val_loss: 11.8562
# Epoch 54/100
# 3/3 [==============================] - 0s 15ms/step - loss: 8.4266 - val_loss: 12.0840
# Epoch 55/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.3888 - val_loss: 12.3295
# Epoch 56/100
# 3/3 [==============================] - 0s 21ms/step - loss: 8.3997 - val_loss: 12.3440
# Epoch 57/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.4164 - val_loss: 12.1737
# Epoch 58/100
# 3/3 [==============================] - 0s 15ms/step - loss: 8.3358 - val_loss: 11.7442
# Epoch 59/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.3066 - val_loss: 11.8876
# Epoch 60/100
# 3/3 [==============================] - 0s 15ms/step - loss: 8.3257 - val_loss: 12.0801
# Epoch 61/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.3006 - val_loss: 12.0491
# Epoch 62/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.3434 - val_loss: 12.0307
# Epoch 63/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.2627 - val_loss: 11.7694
# Epoch 64/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.2299 - val_loss: 11.7627
# Epoch 65/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.2238 - val_loss: 11.7613
# Epoch 66/100
# 3/3 [==============================] - 0s 15ms/step - loss: 8.1859 - val_loss: 11.7592
# Epoch 67/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.2680 - val_loss: 11.7581
# Epoch 68/100
# 3/3 [==============================] - 0s 16ms/step - loss: 8.1119 - val_loss: 11.6726
# Epoch 69/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.1734 - val_loss: 11.4694
# Epoch 70/100
# 3/3 [==============================] - 0s 17ms/step - loss: 8.1988 - val_loss: 11.4412
# Epoch 71/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.1467 - val_loss: 11.6155
# Epoch 72/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.0673 - val_loss: 11.5945
# Epoch 73/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.0411 - val_loss: 11.7884
# Epoch 74/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.0759 - val_loss: 11.6111
# Epoch 75/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.0387 - val_loss: 11.6435
# Epoch 76/100
# 3/3 [==============================] - 0s 16ms/step - loss: 8.0875 - val_loss: 11.6895
# Epoch 77/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.0219 - val_loss: 11.8107
# Epoch 78/100
# 3/3 [==============================] - 0s 15ms/step - loss: 8.0697 - val_loss: 11.7958
# Epoch 79/100
# 3/3 [==============================] - 0s 15ms/step - loss: 7.9659 - val_loss: 11.7393
# Epoch 80/100
# 3/3 [==============================] - 0s 15ms/step - loss: 8.0248 - val_loss: 11.8570
# Epoch 81/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.0637 - val_loss: 11.6572
# Epoch 82/100
# 3/3 [==============================] - 0s 20ms/step - loss: 7.9496 - val_loss: 11.6411
# Epoch 83/100
# 3/3 [==============================] - 0s 15ms/step - loss: 7.9897 - val_loss: 11.3304
# Epoch 84/100
# 3/3 [==============================] - 0s 15ms/step - loss: 7.9887 - val_loss: 11.5432
# Epoch 85/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.0106 - val_loss: 11.6187
# Epoch 86/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.0160 - val_loss: 11.5087
# Epoch 87/100
# 3/3 [==============================] - 0s 14ms/step - loss: 7.9188 - val_loss: 11.6585
# Epoch 88/100
# 3/3 [==============================] - 0s 15ms/step - loss: 7.8832 - val_loss: 11.8279
# Epoch 89/100
# 3/3 [==============================] - 0s 14ms/step - loss: 7.9360 - val_loss: 11.7412
# Epoch 90/100
# 3/3 [==============================] - 0s 14ms/step - loss: 7.8528 - val_loss: 11.4222
# Epoch 91/100
# 3/3 [==============================] - 0s 14ms/step - loss: 7.8642 - val_loss: 11.5557
# Epoch 92/100
# 3/3 [==============================] - 0s 20ms/step - loss: 7.8672 - val_loss: 11.4684
# Epoch 93/100
# 3/3 [==============================] - 0s 25ms/step - loss: 7.8710 - val_loss: 11.4227
# Epoch 94/100
# 3/3 [==============================] - 0s 20ms/step - loss: 7.7811 - val_loss: 11.4166
# Epoch 95/100
# 3/3 [==============================] - 0s 21ms/step - loss: 7.8045 - val_loss: 11.3591
# Epoch 96/100
# 3/3 [==============================] - 0s 23ms/step - loss: 7.8149 - val_loss: 11.2578
# Epoch 97/100
# 3/3 [==============================] - 0s 23ms/step - loss: 7.7502 - val_loss: 11.4507
# Epoch 98/100
# 3/3 [==============================] - 0s 21ms/step - loss: 7.7491 - val_loss: 11.2974
# Epoch 99/100
# 3/3 [==============================] - 0s 29ms/step - loss: 7.7586 - val_loss: 11.3445
# Epoch 100/100
# 3/3 [==============================] - 0s 25ms/step - loss: 7.6873 - val_loss: 11.4142

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Still going down! As a self-study exercise, keep training the model until you see an increase in validation loss. You should train until this happen, so keep an eye in your models!
#
# And how did we do in the test set? The "evaluate" function allows us to validate on new data.

# %%
model.evaluate(test_data, test_targets)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 20.6194
# 20.61943244934082

# %% [markdown]
# We can use this number to compare against other models. Or take the square root to get an idea of the average error to be incurred, and then decide.
#
# Alternatively, if we want to get the value of the predictions, we can use the following command, which returns a prediction over the test data.

# %%
model.predict(test_data)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# array([[ 7.4946275],
#        [17.379782 ],
#        [21.443367 ],
#        [32.201077 ],
#        [24.268816 ],
#        [18.838203 ],
#        [27.100079 ],
#        [21.56356  ],
#        [19.190144 ],
#        [21.931772 ],
#        [12.428919 ],
#        [16.253826 ],
#        [15.201318 ],
#        [41.219902 ],
#        [19.277645 ],
#        [19.8516   ],
#        [26.88377  ],
#        [19.872904 ],
#        [18.542538 ],
#        [25.9542   ],
#        [10.58375  ],
#        [15.571727 ],
#        [20.063778 ],
#        [15.478206 ],
#        [20.960876 ],
#        [25.448137 ],
#        [30.083954 ],
#        [26.84119  ],
#        [10.11998  ],
#        [21.539097 ],
#        [19.392433 ],
#        [13.689179 ],
#        [33.787746 ],
#        [25.504389 ],
#        [18.69193  ],
#        [ 8.255118 ],
#        [15.339709 ],
#        [16.655233 ],
#        [21.00811  ],
#        [25.64978  ],
#        [28.557983 ],
#        [26.643784 ],
#        [13.955847 ],
#        [40.64174  ],
#        [29.337492 ],
#        [23.513395 ],
#        [25.734926 ],
#        [16.211107 ],
#        [23.18422  ],
#        [22.23695  ],
#        [33.018063 ],
#        [18.816608 ],
#        [11.511979 ],
#        [15.882436 ],
#        [36.397026 ],
#        [27.03792  ],
#        [12.701825 ],
#        [47.84561  ],
#        [34.710762 ],
#        [23.03682  ],
#        [25.678297 ],
#        [17.273651 ],
#        [13.95633  ],
#        [17.708677 ],
#        [22.8409   ],
#        [21.973671 ],
#        [12.670621 ],
#        [22.542952 ],
#        [12.826143 ],
#        [ 5.7452273],
#        [26.292889 ],
#        [28.64943  ],
#        [23.92144  ],
#        [13.848861 ],
#        [26.247345 ],
#        [16.908945 ],
#        [20.595858 ],
#        [23.751938 ],
#        [33.874306 ],
#        [10.359525 ],
#        [19.5157   ],
#        [37.81923  ],
#        [15.316815 ],
#        [13.604541 ],
#        [16.795055 ],
#        [17.715504 ],
#        [21.134886 ],
#        [20.664127 ],
#        [22.41809  ],
#        [32.429264 ],
#        [20.196075 ],
#        [19.957943 ],
#        [25.813927 ],
#        [41.063778 ],
#        [34.851143 ],
#        [18.637966 ],
#        [35.5877   ],
#        [50.727306 ],
#        [27.39682  ],
#        [47.99502  ],
#        [31.879028 ],
#        [19.297188 ]], dtype=float32)

# %% [markdown]
# And that's it! We have our first shallow neural network trained. In future labs we will be adding complexity to this by for example using more complex text-based embeddings, images, etc.

# %% [markdown]
# # Self Study
#
# Go through this example again, but now following Chapter 3.6 of Chollet's book. There you'll learn how to use Cross-Validation to model this example. Modify the activations and the size of the network. Try, for example:
#
# - Using SeLU instead of ReLU
# - Adding one more hidden layer
# - Changing the number of neurons from 64 to 128
# - ...etc
#
# Can you reach a better predictive capability over the test set? Creating an architecture is an art, so be creative and do your best effort!
